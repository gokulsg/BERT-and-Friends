# %%
## BERT and Friends - Project ##

# %%
# !pip install datasets
# !pip install transformers
# !pip install evaluate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.5.1-py3-none-any.whl (431 kB)
#      |████████████████████████████████| 431 kB 9.3 MB/s
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 56.7 MB/s
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.12.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 55.3 MB/s
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.8.2)
# Collecting huggingface-hub<1.0.0,>=0.1.0
#   Downloading huggingface_hub-0.9.1-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 18.4 MB/s
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.1.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.8.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 54.3 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: urllib3, xxhash, responses, multiprocess, huggingface-hub, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed datasets-2.5.1 huggingface-hub-0.9.1 multiprocess-0.70.13 responses-0.18.0 urllib3-1.25.11 xxhash-3.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.22.1-py3-none-any.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 27.0 MB/s
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.9.1)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 63.9 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.9.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Installing collected packages: tokenizers, transformers
# Successfully installed tokenizers-0.12.1 transformers-4.22.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting evaluate
#   Downloading evaluate-0.2.2-py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 7.3 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from evaluate) (1.3.5)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from evaluate) (4.64.1)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from evaluate) (2022.8.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from evaluate) (0.3.5.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from evaluate) (0.70.13)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from evaluate) (2.23.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from evaluate) (3.0.0)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from evaluate) (2.5.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from evaluate) (0.9.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from evaluate) (1.21.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from evaluate) (4.12.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from evaluate) (21.3)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from evaluate) (0.18.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets>=2.0.0->evaluate) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.1.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.1.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.13.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.7.0->evaluate) (3.8.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.7.0->evaluate) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->evaluate) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->evaluate) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->evaluate) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->evaluate) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->evaluate) (3.0.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->evaluate) (3.8.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->evaluate) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->evaluate) (1.15.0)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.2.2

# %% [markdown]
# In this Project, There are three important sections:
#
# **Part 1:** We will fine-tune the BERT-base, distilRoBERTa and DistilBERT and BERT-tiny (student) model on the Amazon Massive dataset.
#
# **Part 2:** We will perform task-specific Knowledge Distillation using the Amazon Massive dataset.
#
# Student model: BERT-tiny (2 layers and 128 hidden dimension and 2 attention heads)
#
# We use our fine-tuned models in part-1 as teachers. The Knowledge distillation is performed in three different settings:
#
# 1.   Only with BERT model
# 2.   Only with distilBERT model
# 3.   With the combination of two models - BERT and distilBERT model
#
# **Part 3:** We will analyze the model size and the processing time

# %%
## Importing the Libraries and loading the dataset ##

from datasets import load_dataset
from transformers import AutoTokenizer, DataCollatorWithPadding
from transformers import TrainingArguments, Trainer, AutoModelForSequenceClassification, EarlyStoppingCallback
from huggingface_hub import notebook_login, HfFolder, HfApi
from collections import Counter
import evaluate
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

raw_datasets = load_dataset('AmazonScience/massive', 'en-US') ## Considering only the English dataset ##
raw_datasets
# Out:
# WARNING:datasets.builder:Found cached dataset massive (/root/.cache/huggingface/datasets/AmazonScience___massive/en-US/1.0.0/c06e96faea378f5cbba9f6ba50b7ea33fb3f91d4256bfa26cd23a54421d154e5)
#   0%|          | 0/3 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'locale', 'partition', 'scenario', 'intent', 'utt', 'annot_utt', 'worker_id', 'slot_method', 'judgments'],
#         num_rows: 11514
#     })
#     validation: Dataset({
#         features: ['id', 'locale', 'partition', 'scenario', 'intent', 'utt', 'annot_utt', 'worker_id', 'slot_method', 'judgments'],
#         num_rows: 2033
#     })
#     test: Dataset({
#         features: ['id', 'locale', 'partition', 'scenario', 'intent', 'utt', 'annot_utt', 'worker_id', 'slot_method', 'judgments'],
#         num_rows: 2974
#     })
# })

# %%
## Checking if GPU is available ##

device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %%
## Logging into Huggingface hub ##

notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub. Run the following command in your terminal in case you want to set this credential helper as the default
#
# git config --global credential.helper store

# %%
### Ref: https://huggingface.co/google/bert_uncased_L-2_H-128_A-2 ### - BERT Student model ###

# %% [markdown]
# # Using BERT-base model for Knowledge Distillation

# %%
# Name for the repository on the huggingface hub #

repo_name = "bert-tiny-Massive-intent-KD-BERT"

# %%
## Teacher model: https://huggingface.co/gokuls/bert-base-Massive-intent ##

# %%
student_id = "google/bert_uncased_L-2_H-128_A-2" ## using bert-tiny model
teacher_id = "gokuls/bert-base-Massive-intent" ## Our pre-trained BERT model is used as teacher

# %%
## Checking if the tokenizers of teacher and student model produces the same output ##

# tokenizer initialization #
teacher_tokenizer = AutoTokenizer.from_pretrained(teacher_id)
student_tokenizer = AutoTokenizer.from_pretrained(student_id)

# sample input #
sample = "Testing tokenizers."

# Sanity check #
print('Teacher tokenizer: ', teacher_tokenizer(sample))
print('Student tokenizer: ', student_tokenizer(sample))
# Out:
# Downloading:   0%|          | 0.00/348 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/711k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/382 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Teacher tokenizer:  {'input_ids': [101, 5604, 19204, 17629, 2015, 1012, 102], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1]}
# Student tokenizer:  {'input_ids': [101, 5604, 19204, 17629, 2015, 1012, 102], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1]}

# %%
## Tokenization outputs are similar ##

# %%
tokenizer = AutoTokenizer.from_pretrained(teacher_id)

# %%
## Tokenization ##

def tokenize_function(example):
    return tokenizer(example["utt"], truncation=True)

tokenized_datasets = raw_datasets.map(tokenize_function, batched=True)
# Out:
#   0%|          | 0/12 [00:00<?, ?ba/s]
#   0%|          | 0/3 [00:00<?, ?ba/s]
#   0%|          | 0/3 [00:00<?, ?ba/s]

# %%
## Data Pre-processing ##

tokenized_datasets = tokenized_datasets.remove_columns(['id', 'locale', 'partition','scenario','annot_utt', 'utt', 'worker_id', 'slot_method', 'judgments']) ## removing unwanted columns ##
tokenized_datasets = tokenized_datasets.rename_column("intent", "labels")
tokenized_datasets.set_format("torch")
tokenized_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['labels', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 11514
#     })
#     validation: Dataset({
#         features: ['labels', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 2033
#     })
#     test: Dataset({
#         features: ['labels', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 2974
#     })
# })

# %%
class DistillationTrainingArguments(TrainingArguments):
    def __init__(self, *args, alpha=0.5, temperature=2.0, **kwargs):
        super().__init__(*args, **kwargs)
        
        self.alpha = alpha
        self.temperature = temperature
        
class DistillationTrainer(Trainer):
    def __init__(self, *args, teacher_model=None, **kwargs):
        super().__init__(*args, **kwargs)
        self.teacher = teacher_model
        # student and teacher on same device #
        self._move_model_to_device(self.teacher,self.model.device)
        self.teacher.eval()

    def compute_loss(self, model, inputs, return_outputs=False):

        # compute student output #
        outputs_student = model(**inputs)
        student_loss=outputs_student.loss
        # compute teacher output #
        with torch.no_grad():
            outputs_teacher = self.teacher(**inputs)
        
        # assert size #
        assert outputs_student.logits.size() == outputs_teacher.logits.size()
        
        # Soften probabilities and compute distillation loss #
        loss_function = nn.KLDivLoss(reduction="batchmean")
        loss_logits = (loss_function(
            F.log_softmax(outputs_student.logits / self.args.temperature, dim=-1),
            F.softmax(outputs_teacher.logits / self.args.temperature, dim=-1)) * (self.args.temperature ** 2))
        # Return weighted student loss #
        loss = self.args.alpha * student_loss + (1. - self.args.alpha) * loss_logits
        return (loss, outputs_student) if return_outputs else loss

# %%
# create label2id, id2label dicts #
labels = tokenized_datasets["train"].features["labels"].names
num_labels = len(labels)
label2id, id2label = dict(), dict()
for i, label in enumerate(labels):
    label2id[label] = str(i)
    id2label[str(i)] = label

# training args #
training_args = DistillationTrainingArguments(
    output_dir=repo_name,
    num_train_epochs=50,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    fp16=True,
    learning_rate=5e-5,
    seed=33,
    # logging & evaluation strategies #
    logging_dir=f"{repo_name}/logs",
    logging_strategy="epoch",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    save_total_limit=2,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    report_to="tensorboard",
    # push to hub parameters #
    push_to_hub=True,
    hub_strategy="every_save",
    hub_model_id=repo_name,
    hub_token=HfFolder.get_token(),
    # distilation parameters #
    alpha=0.5,
    temperature=3.0
    )

# data_collator #
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# Teacher model #
teacher_model = AutoModelForSequenceClassification.from_pretrained(
    teacher_id,
    num_labels=num_labels, 
    id2label=id2label,
    label2id=label2id,
)

# Student model #
student_model = AutoModelForSequenceClassification.from_pretrained(
    student_id,
    num_labels=num_labels, 
    id2label=id2label,
    label2id=label2id,
)
# Out:
# Downloading:   0%|          | 0.00/3.25k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/17.7M [00:00<?, ?B/s]
# Some weights of the model checkpoint at google/bert_uncased_L-2_H-128_A-2 were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at google/bert_uncased_L-2_H-128_A-2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
## Evaluation metric ##

def compute_metrics(eval_preds):
    metric_acc = evaluate.load("accuracy")
    #metric_f1 = evaluate.load("f1")
    logits, labels = eval_preds
    predictions = np.argmax(logits, axis=-1)
    #return {'accuracy' : metric_acc.compute(predictions=predictions, references=labels), 'f1' : metric_f1.compute(predictions=predictions, references=labels, average= 'micro')}
    return metric_acc.compute(predictions=predictions, references=labels)

# %%
## Trainer ##

trainer = DistillationTrainer(
    student_model,
    training_args,
    teacher_model=teacher_model,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
    callbacks = [EarlyStoppingCallback(early_stopping_patience = 3)],
)
# Out:
# Cloning https://huggingface.co/gokuls/bert-tiny-Massive-intent-KD-BERT into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/gokuls/bert-tiny-Massive-intent-KD-BERT into local empty directory.
# Download file pytorch_model.bin:   0%|          | 3.48k/16.8M [00:00<?, ?B/s]
# Download file logs/1663960776.3205633/events.out.tfevents.1663960776.bf5406322ee0.68.1: 100%|##########| 5.43k…
# Download file training_args.bin: 100%|##########| 3.36k/3.36k [00:00<?, ?B/s]
# Clean file logs/1663960776.3205633/events.out.tfevents.1663960776.bf5406322ee0.68.1:  18%|#8        | 1.00k/5.…
# Clean file training_args.bin:  30%|##9       | 1.00k/3.36k [00:00<?, ?B/s]
# Download file logs/events.out.tfevents.1663960776.bf5406322ee0.68.0:  25%|##5       | 3.48k/13.9k [00:00<?, ?B…
# Clean file logs/events.out.tfevents.1663960776.bf5406322ee0.68.0:   7%|7         | 1.00k/13.9k [00:00<?, ?B/s]
# Clean file pytorch_model.bin:   0%|          | 1.00k/16.8M [00:00<?, ?B/s]
# Using cuda_amp half precision backend

# %%
## Training ##

trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 11514
#   Num Epochs = 50
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 36000
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='30960' max='36000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [30960/36000 28:33 < 04:39, 18.06 it/s, Epoch 43/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>5.830000</td>
#       <td>4.882554</td>
#       <td>0.304968</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.760200</td>
#       <td>3.990367</td>
#       <td>0.419085</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.030100</td>
#       <td>3.380615</td>
#       <td>0.503197</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.479700</td>
#       <td>2.906472</td>
#       <td>0.596655</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.035200</td>
#       <td>2.538918</td>
#       <td>0.659616</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.678700</td>
#       <td>2.234223</td>
#       <td>0.704378</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.364400</td>
#       <td>1.987251</td>
#       <td>0.735366</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.114500</td>
#       <td>1.792825</td>
#       <td>0.746188</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.896000</td>
#       <td>1.629283</td>
#       <td>0.764388</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.713800</td>
#       <td>1.506156</td>
#       <td>0.775209</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.562500</td>
#       <td>1.392270</td>
#       <td>0.788490</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.422900</td>
#       <td>1.309171</td>
#       <td>0.797836</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.308000</td>
#       <td>1.236397</td>
#       <td>0.801771</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.201000</td>
#       <td>1.175910</td>
#       <td>0.815544</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.118700</td>
#       <td>1.132172</td>
#       <td>0.821446</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.038400</td>
#       <td>1.098982</td>
#       <td>0.823414</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.976000</td>
#       <td>1.061517</td>
#       <td>0.830792</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.916300</td>
#       <td>1.037743</td>
#       <td>0.832759</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.861100</td>
#       <td>1.005380</td>
#       <td>0.833743</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.812000</td>
#       <td>0.992611</td>
#       <td>0.836695</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.772100</td>
#       <td>0.971186</td>
#       <td>0.838170</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.739300</td>
#       <td>0.958636</td>
#       <td>0.835711</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.705900</td>
#       <td>0.942816</td>
#       <td>0.837186</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.674100</td>
#       <td>0.937743</td>
#       <td>0.839646</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.655200</td>
#       <td>0.922889</td>
#       <td>0.837678</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.627000</td>
#       <td>0.909994</td>
#       <td>0.841613</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.597200</td>
#       <td>0.902776</td>
#       <td>0.841613</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.578400</td>
#       <td>0.899635</td>
#       <td>0.840630</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.559500</td>
#       <td>0.883289</td>
#       <td>0.845057</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.543800</td>
#       <td>0.877199</td>
#       <td>0.847516</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.521800</td>
#       <td>0.875754</td>
#       <td>0.845057</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.509000</td>
#       <td>0.872814</td>
#       <td>0.848008</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.489300</td>
#       <td>0.864033</td>
#       <td>0.848008</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.494800</td>
#       <td>0.854117</td>
#       <td>0.847516</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.472200</td>
#       <td>0.859550</td>
#       <td>0.849484</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.468000</td>
#       <td>0.848758</td>
#       <td>0.849484</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.451700</td>
#       <td>0.846021</td>
#       <td>0.850467</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.446200</td>
#       <td>0.844953</td>
#       <td>0.848500</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.439600</td>
#       <td>0.842229</td>
#       <td>0.848992</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.427000</td>
#       <td>0.837999</td>
#       <td>0.853419</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.428700</td>
#       <td>0.838545</td>
#       <td>0.848008</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.422200</td>
#       <td>0.831904</td>
#       <td>0.850959</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.421000</td>
#       <td>0.829586</td>
#       <td>0.850959</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-720
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-720/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-720/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-720/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-720/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-1440
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-1440/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-1440/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-1440/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-1440/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-2160
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-2160/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-2160/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-2160/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-2160/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-720] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-2880
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-2880/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-2880/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-2880/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-2880/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-1440] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-3600
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-3600/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-3600/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-3600/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-3600/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-2160] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-4320
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-4320/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-4320/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-4320/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-4320/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-2880] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-5040
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-5040/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-5040/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-5040/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-5040/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-3600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-5760
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-5760/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-5760/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-5760/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-5760/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-4320] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-6480
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-6480/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-6480/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-6480/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-6480/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-5040] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-7200
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-7200/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-7200/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-7200/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-7200/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-5760] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-7920
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-7920/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-7920/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-7920/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-7920/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-6480] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-8640
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-8640/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-8640/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-8640/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-8640/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-7200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-9360
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-9360/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-9360/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-9360/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-9360/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-7920] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-10080
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-10080/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-10080/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-10080/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-10080/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-8640] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-10800
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-10800/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-10800/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-10800/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-10800/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-9360] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-11520
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-11520/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-11520/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-11520/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-11520/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-10080] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-12240
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-12240/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-12240/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-12240/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-12240/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-10800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-12960
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-12960/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-12960/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-12960/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-12960/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-11520] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-13680
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-13680/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-13680/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-13680/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-13680/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-12240] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-14400
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-14400/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-14400/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-14400/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-14400/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-12960] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-15120
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-15120/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-15120/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-15120/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-15120/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-13680] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-15840
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-15840/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-15840/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-15840/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-15840/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-14400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-16560
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-16560/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-16560/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-16560/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-16560/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-15840] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-17280
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-17280/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-17280/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-17280/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-17280/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-15120] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-18000
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-18000/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-18000/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-18000/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-18000/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-16560] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-18720
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-18720/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-18720/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-18720/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-18720/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-17280] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-19440
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-19440/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-19440/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-19440/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-19440/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-18000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-20160
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-20160/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-20160/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-20160/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-20160/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-19440] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-20880
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-20880/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-20880/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-20880/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-20880/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-18720] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-21600
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-21600/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-21600/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-21600/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-21600/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-20160] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-22320
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-22320/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-22320/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-22320/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-22320/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-20880] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-23040
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-23040/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-23040/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-23040/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-23040/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-21600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-23760
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-23760/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-23760/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-23760/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-23760/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-22320] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-24480
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-24480/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-24480/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-24480/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-24480/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-23760] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-25200
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-25200/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-25200/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-25200/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-25200/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-23040] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-25920
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-25920/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-25920/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-25920/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-25920/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-24480] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-26640
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-26640/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-26640/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-26640/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-26640/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-25200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-27360
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-27360/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-27360/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-27360/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-27360/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-25920] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-28080
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-28080/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-28080/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-28080/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-28080/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-27360] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-28800
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-28800/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-28800/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-28800/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-28800/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-26640] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-29520
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-29520/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-29520/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-29520/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-29520/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-28080] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-30240
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-30240/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-30240/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-30240/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-30240/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-29520] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT/checkpoint-30960
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-30960/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-30960/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-30960/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/checkpoint-30960/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT/checkpoint-30240] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from bert-tiny-Massive-intent-KD-BERT/checkpoint-28800 (score: 0.853418593212002).
# TrainOutput(global_step=30960, training_loss=1.292167179590664, metrics={'train_runtime': 1716.6288, 'train_samples_per_second': 335.367, 'train_steps_per_second': 20.971, 'total_flos': 21871399613904.0, 'train_loss': 1.292167179590664, 'epoch': 43.0})

# %%
## After the training the Best model will be used. Now evaluating the best model ##

## Evaluate ##

trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
#     <div>
#
#       <progress value='128' max='128' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [128/128 00:02]
#     </div>
# {'eval_loss': 0.8379986882209778,
#  'eval_accuracy': 0.853418593212002,
#  'eval_runtime': 4.872,
#  'eval_samples_per_second': 417.279,
#  'eval_steps_per_second': 26.272,
#  'epoch': 43.0}

# %%
## Evaluating the model on Test set ##

print('\nTest results : \n\n', trainer.predict(tokenized_datasets["test"]).metrics)
# Out:
# ***** Running Prediction *****
#   Num examples = 2974
#   Batch size = 16
# Test results :
#
#  {'test_loss': 0.9081733822822571, 'test_accuracy': 0.8328850033624747, 'test_runtime': 7.7733, 'test_samples_per_second': 382.593, 'test_steps_per_second': 23.928}

# %%
## Computing All the other performance evaluation metics (precision, recall and f1) on the test set ##

## Predicted values ##

test_result = trainer.predict(tokenized_datasets["test"])
predicted_values = np.argmax(test_result.predictions, axis=1)
print("Predicted values : ", predicted_values)

## Actual values ##

actual_values = test_result.label_ids
print('Actual values : ', actual_values)

## Getting label id and names ##

target_names = list(label2id.keys())
labels = list(map(int, list(id2label.keys()))) ## Converting list of strings to list of integers ##


## Getting the classification report using sklearn ##

from sklearn.metrics import classification_report, accuracy_score

print('Accuracy : ', accuracy_score(actual_values, predicted_values))
print(classification_report(actual_values, predicted_values, labels= labels, target_names= target_names))
# Out:
# ***** Running Prediction *****
#   Num examples = 2974
#   Batch size = 16
# Predicted values :  [48 46 13 ... 44 44 44]
# Actual values :  [48 46  1 ... 44 44 44]
# Accuracy :  0.8328850033624747
#                           precision    recall  f1-score   support
#
#           datetime_query       0.86      0.90      0.88        88
#      iot_hue_lightchange       0.87      0.94      0.91        36
#         transport_ticket       1.00      0.94      0.97        35
#           takeaway_query       0.90      0.74      0.81        35
#                 qa_stock       0.83      0.92      0.87        26
#            general_greet       0.00      0.00      0.00         1
#    recommendation_events       0.76      0.65      0.70        43
#        music_dislikeness       0.00      0.00      0.00         4
#             iot_wemo_off       0.92      0.67      0.77        18
#           cooking_recipe       0.85      0.88      0.86        72
#              qa_currency       0.95      0.95      0.95        39
#        transport_traffic       0.79      1.00      0.88        15
#           general_quirky       0.58      0.51      0.54       169
#            weather_query       0.91      0.94      0.92       156
#          audio_volume_up       0.53      0.77      0.62        13
#         email_addcontact       0.60      0.50      0.55        12
#           takeaway_order       0.75      0.82      0.78        22
#       email_querycontact       0.69      0.69      0.69        26
#          iot_hue_lightup       0.96      0.89      0.92        27
# recommendation_locations       0.88      0.90      0.89        31
#           play_audiobook       0.83      0.71      0.76        41
#        lists_createoradd       0.76      0.87      0.81        39
#               news_query       0.80      0.83      0.82       124
#              alarm_query       0.91      0.94      0.93        34
#              iot_wemo_on       1.00      0.90      0.95        10
#             general_joke       1.00      0.89      0.94        19
#            qa_definition       0.81      0.77      0.79        57
#             social_query       0.83      0.76      0.79        25
#           music_settings       0.67      0.33      0.44         6
#       audio_volume_other       0.00      0.00      0.00         6
#          calendar_remove       0.86      0.97      0.91        67
#         iot_hue_lightdim       0.91      0.95      0.93        21
#           calendar_query       0.69      0.81      0.74       126
#          email_sendemail       0.92      0.93      0.93       114
#             iot_cleaning       0.96      0.88      0.92        26
#        audio_volume_down       0.89      0.73      0.80        11
#               play_radio       0.89      0.89      0.89        72
#            cooking_query       0.00      0.00      0.00         0
#         datetime_convert       0.80      0.53      0.64        15
#                 qa_maths       0.72      0.84      0.78        25
#         iot_hue_lightoff       0.84      0.88      0.86        43
#          iot_hue_lighton       0.00      0.00      0.00         3
#          transport_query       0.88      0.71      0.78        51
#           music_likeness       0.83      0.69      0.76        36
#              email_query       0.90      0.94      0.92       119
#               play_music       0.81      0.90      0.85       176
#        audio_volume_mute       0.96      0.84      0.90        32
#              social_post       0.95      0.89      0.92        81
#                alarm_set       0.88      0.93      0.90        41
#               qa_factoid       0.66      0.74      0.70       141
#             calendar_set       0.90      0.89      0.90       209
#                play_game       0.90      0.74      0.81        35
#             alarm_remove       0.82      0.86      0.84        21
#             lists_remove       0.96      0.85      0.90        52
#           transport_taxi       0.88      1.00      0.94        23
#    recommendation_movies       0.70      0.70      0.70        20
#               iot_coffee       0.94      0.94      0.94        36
#              music_query       0.76      0.91      0.83        35
#            play_podcasts       0.98      0.89      0.93        63
#              lists_query       0.89      0.78      0.83        51
#
#                micro avg       0.83      0.83      0.83      2974
#                macro avg       0.77      0.75      0.76      2974
#             weighted avg       0.83      0.83      0.83      2974
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
## Saving the model on the hugging face hub ##

# save best model, metrics and create model card #

trainer.create_model_card(model_name=training_args.hub_model_id)
trainer.push_to_hub()


## Link for the model webpage ##

whoami = HfApi().whoami()
username = whoami['name']

print(f"Model webpage link: https://huggingface.co/{username}/{repo_name}")
# Out:
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT
# Configuration saved in bert-tiny-Massive-intent-KD-BERT/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT/special_tokens_map.json
# Upload file logs/events.out.tfevents.1664042979.ce181c7f3327.67.0:  12%|#2        | 3.34k/27.6k [00:00<?, ?B/s…
# Upload file logs/events.out.tfevents.1664044700.ce181c7f3327.67.2: 100%|##########| 369/369 [00:00<?, ?B/s]
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/gokuls/bert-tiny-Massive-intent-KD-BERT
#    76a41e4..7fe0344  main -> main
#
# WARNING:huggingface_hub.repository:remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/gokuls/bert-tiny-Massive-intent-KD-BERT
#    76a41e4..7fe0344  main -> main
# Model webpage link: https://huggingface.co/gokuls/bert-tiny-Massive-intent-KD-BERT

# %% [markdown]
# # Using distilBERT model for Knowledge Distillation

# %%
# Name for the repository on the huggingface hub #

repo_name = "bert-tiny-Massive-intent-KD-distilBERT"

# %%
## Teacher model: https://huggingface.co/gokuls/distilbert-base-Massive-intent ##

# %%
student_id = "google/bert_uncased_L-2_H-128_A-2" ## using bert-tiny model
teacher_id = "gokuls/distilbert-base-Massive-intent" ## Our pre-trained distilBERT model is used as teacher

# %%
## Checking if the tokenizers of teacher and student model produces the same output ##

# tokenizer initialization #
teacher_tokenizer = AutoTokenizer.from_pretrained(teacher_id)
student_tokenizer = AutoTokenizer.from_pretrained(student_id)

# sample input #
sample = "Testing tokenizers."

# Sanity check #
print('Teacher tokenizer: ', teacher_tokenizer(sample))
print('Student tokenizer: ', student_tokenizer(sample))
# Out:
# Downloading:   0%|          | 0.00/360 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/711k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/125 [00:00<?, ?B/s]
# loading file vocab.txt from cache at /root/.cache/huggingface/hub/models--gokuls--distilbert-base-Massive-intent/snapshots/1282c5096ee4deac235f13f2a1f4a5571f70852c/vocab.txt
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--gokuls--distilbert-base-Massive-intent/snapshots/1282c5096ee4deac235f13f2a1f4a5571f70852c/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--gokuls--distilbert-base-Massive-intent/snapshots/1282c5096ee4deac235f13f2a1f4a5571f70852c/special_tokens_map.json
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--gokuls--distilbert-base-Massive-intent/snapshots/1282c5096ee4deac235f13f2a1f4a5571f70852c/tokenizer_config.json
# Could not locate the tokenizer configuration file, will try to use the model config instead.
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--google--bert_uncased_L-2_H-128_A-2/snapshots/1ae49ff827beda5996998802695c4cac8e9932c6/config.json
# Model config BertConfig {
#   "_name_or_path": "google/bert_uncased_L-2_H-128_A-2",
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 128,
#   "initializer_range": 0.02,
#   "intermediate_size": 512,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 2,
#   "num_hidden_layers": 2,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.22.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading file vocab.txt from cache at /root/.cache/huggingface/hub/models--google--bert_uncased_L-2_H-128_A-2/snapshots/1ae49ff827beda5996998802695c4cac8e9932c6/vocab.txt
# loading file tokenizer.json from cache at None
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at None
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--google--bert_uncased_L-2_H-128_A-2/snapshots/1ae49ff827beda5996998802695c4cac8e9932c6/config.json
# Model config BertConfig {
#   "_name_or_path": "google/bert_uncased_L-2_H-128_A-2",
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 128,
#   "initializer_range": 0.02,
#   "intermediate_size": 512,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 2,
#   "num_hidden_layers": 2,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.22.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--google--bert_uncased_L-2_H-128_A-2/snapshots/1ae49ff827beda5996998802695c4cac8e9932c6/config.json
# Model config BertConfig {
#   "_name_or_path": "google/bert_uncased_L-2_H-128_A-2",
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 128,
#   "initializer_range": 0.02,
#   "intermediate_size": 512,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 2,
#   "num_hidden_layers": 2,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.22.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
# Teacher tokenizer:  {'input_ids': [101, 5604, 19204, 17629, 2015, 1012, 102], 'attention_mask': [1, 1, 1, 1, 1, 1, 1]}
# Student tokenizer:  {'input_ids': [101, 5604, 19204, 17629, 2015, 1012, 102], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1]}

# %%
## Tokenization outputs are similar ##

# %%
tokenizer = AutoTokenizer.from_pretrained(teacher_id)
# Out:
# loading file vocab.txt from cache at /root/.cache/huggingface/hub/models--gokuls--distilbert-base-Massive-intent/snapshots/1282c5096ee4deac235f13f2a1f4a5571f70852c/vocab.txt
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--gokuls--distilbert-base-Massive-intent/snapshots/1282c5096ee4deac235f13f2a1f4a5571f70852c/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--gokuls--distilbert-base-Massive-intent/snapshots/1282c5096ee4deac235f13f2a1f4a5571f70852c/special_tokens_map.json
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--gokuls--distilbert-base-Massive-intent/snapshots/1282c5096ee4deac235f13f2a1f4a5571f70852c/tokenizer_config.json

# %%
## Tokenization ##

def tokenize_function(example):
    return tokenizer(example["utt"], truncation=True)

tokenized_datasets = raw_datasets.map(tokenize_function, batched=True)
# Out:
#   0%|          | 0/12 [00:00<?, ?ba/s]
#   0%|          | 0/3 [00:00<?, ?ba/s]
#   0%|          | 0/3 [00:00<?, ?ba/s]

# %%
## Data Pre-processing ##

tokenized_datasets = tokenized_datasets.remove_columns(['id', 'locale', 'partition','scenario','annot_utt', 'utt', 'worker_id', 'slot_method', 'judgments']) ## removing unwanted columns ##
tokenized_datasets = tokenized_datasets.rename_column("intent", "labels")
tokenized_datasets.set_format("torch")
tokenized_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['labels', 'input_ids', 'attention_mask'],
#         num_rows: 11514
#     })
#     validation: Dataset({
#         features: ['labels', 'input_ids', 'attention_mask'],
#         num_rows: 2033
#     })
#     test: Dataset({
#         features: ['labels', 'input_ids', 'attention_mask'],
#         num_rows: 2974
#     })
# })

# %%
class DistillationTrainingArguments(TrainingArguments):
    def __init__(self, *args, alpha=0.5, temperature=2.0, **kwargs):
        super().__init__(*args, **kwargs)
        
        self.alpha = alpha
        self.temperature = temperature
        
class DistillationTrainer(Trainer):
    def __init__(self, *args, teacher_model=None, **kwargs):
        super().__init__(*args, **kwargs)
        self.teacher = teacher_model
        # student and teacher on same device #
        self._move_model_to_device(self.teacher,self.model.device)
        self.teacher.eval()

    def compute_loss(self, model, inputs, return_outputs=False):

        # compute student output #
        outputs_student = model(**inputs)
        student_loss=outputs_student.loss
        # compute teacher output #
        with torch.no_grad():
            outputs_teacher = self.teacher(**inputs)
        
        # assert size #
        assert outputs_student.logits.size() == outputs_teacher.logits.size()
        
        # Soften probabilities and compute distillation loss #
        loss_function = nn.KLDivLoss(reduction="batchmean")
        loss_logits = (loss_function(
            F.log_softmax(outputs_student.logits / self.args.temperature, dim=-1),
            F.softmax(outputs_teacher.logits / self.args.temperature, dim=-1)) * (self.args.temperature ** 2))
        # Return weighted student loss #
        loss = self.args.alpha * student_loss + (1. - self.args.alpha) * loss_logits
        return (loss, outputs_student) if return_outputs else loss

# %%
# create label2id, id2label dicts #
labels = tokenized_datasets["train"].features["labels"].names
num_labels = len(labels)
label2id, id2label = dict(), dict()
for i, label in enumerate(labels):
    label2id[label] = str(i)
    id2label[str(i)] = label

# training args #
training_args = DistillationTrainingArguments(
    output_dir=repo_name,
    num_train_epochs=50,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    fp16=True,
    learning_rate=5e-5,
    seed=33,
    # logging & evaluation strategies #
    logging_dir=f"{repo_name}/logs",
    logging_strategy="epoch",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    save_total_limit=2,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    report_to="tensorboard",
    # push to hub parameters #
    push_to_hub=True,
    hub_strategy="every_save",
    hub_model_id=repo_name,
    hub_token=HfFolder.get_token(),
    # distilation parameters #
    alpha=0.5,
    temperature=3.0
    )

# data_collator #
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# Teacher model #
teacher_model = AutoModelForSequenceClassification.from_pretrained(
    teacher_id,
    num_labels=num_labels, 
    id2label=id2label,
    label2id=label2id,
)

# Student model #
student_model = AutoModelForSequenceClassification.from_pretrained(
    student_id,
    num_labels=num_labels, 
    id2label=id2label,
    label2id=label2id,
)
# Out:
# PyTorch: setting up devices
# Downloading:   0%|          | 0.00/3.13k [00:00<?, ?B/s]
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--gokuls--distilbert-base-Massive-intent/snapshots/1282c5096ee4deac235f13f2a1f4a5571f70852c/config.json
# Model config DistilBertConfig {
#   "_name_or_path": "gokuls/distilbert-base-Massive-intent",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForSequenceClassification"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "id2label": {
#     "0": "datetime_query",
#     "1": "iot_hue_lightchange",
#     "10": "qa_currency",
#     "11": "transport_traffic",
#     "12": "general_quirky",
#     "13": "weather_query",
#     "14": "audio_volume_up",
#     "15": "email_addcontact",
#     "16": "takeaway_order",
#     "17": "email_querycontact",
#     "18": "iot_hue_lightup",
#     "19": "recommendation_locations",
#     "2": "transport_ticket",
#     "20": "play_audiobook",
#     "21": "lists_createoradd",
#     "22": "news_query",
#     "23": "alarm_query",
#     "24": "iot_wemo_on",
#     "25": "general_joke",
#     "26": "qa_definition",
#     "27": "social_query",
#     "28": "music_settings",
#     "29": "audio_volume_other",
#     "3": "takeaway_query",
#     "30": "calendar_remove",
#     "31": "iot_hue_lightdim",
#     "32": "calendar_query",
#     "33": "email_sendemail",
#     "34": "iot_cleaning",
#     "35": "audio_volume_down",
#     "36": "play_radio",
#     "37": "cooking_query",
#     "38": "datetime_convert",
#     "39": "qa_maths",
#     "4": "qa_stock",
#     "40": "iot_hue_lightoff",
#     "41": "iot_hue_lighton",
#     "42": "transport_query",
#     "43": "music_likeness",
#     "44": "email_query",
#     "45": "play_music",
#     "46": "audio_volume_mute",
#     "47": "social_post",
#     "48": "alarm_set",
#     "49": "qa_factoid",
#     "5": "general_greet",
#     "50": "calendar_set",
#     "51": "play_game",
#     "52": "alarm_remove",
#     "53": "lists_remove",
#     "54": "transport_taxi",
#     "55": "recommendation_movies",
#     "56": "iot_coffee",
#     "57": "music_query",
#     "58": "play_podcasts",
#     "59": "lists_query",
#     "6": "recommendation_events",
#     "7": "music_dislikeness",
#     "8": "iot_wemo_off",
#     "9": "cooking_recipe"
#   },
#   "initializer_range": 0.02,
#   "label2id": {
#     "alarm_query": "23",
#     "alarm_remove": "52",
#     "alarm_set": "48",
#     "audio_volume_down": "35",
#     "audio_volume_mute": "46",
#     "audio_volume_other": "29",
#     "audio_volume_up": "14",
#     "calendar_query": "32",
#     "calendar_remove": "30",
#     "calendar_set": "50",
#     "cooking_query": "37",
#     "cooking_recipe": "9",
#     "datetime_convert": "38",
#     "datetime_query": "0",
#     "email_addcontact": "15",
#     "email_query": "44",
#     "email_querycontact": "17",
#     "email_sendemail": "33",
#     "general_greet": "5",
#     "general_joke": "25",
#     "general_quirky": "12",
#     "iot_cleaning": "34",
#     "iot_coffee": "56",
#     "iot_hue_lightchange": "1",
#     "iot_hue_lightdim": "31",
#     "iot_hue_lightoff": "40",
#     "iot_hue_lighton": "41",
#     "iot_hue_lightup": "18",
#     "iot_wemo_off": "8",
#     "iot_wemo_on": "24",
#     "lists_createoradd": "21",
#     "lists_query": "59",
#     "lists_remove": "53",
#     "music_dislikeness": "7",
#     "music_likeness": "43",
#     "music_query": "57",
#     "music_settings": "28",
#     "news_query": "22",
#     "play_audiobook": "20",
#     "play_game": "51",
#     "play_music": "45",
#     "play_podcasts": "58",
#     "play_radio": "36",
#     "qa_currency": "10",
#     "qa_definition": "26",
#     "qa_factoid": "49",
#     "qa_maths": "39",
#     "qa_stock": "4",
#     "recommendation_events": "6",
#     "recommendation_locations": "19",
#     "recommendation_movies": "55",
#     "social_post": "47",
#     "social_query": "27",
#     "takeaway_order": "16",
#     "takeaway_query": "3",
#     "transport_query": "42",
#     "transport_taxi": "54",
#     "transport_ticket": "2",
#     "transport_traffic": "11",
#     "weather_query": "13"
#   },
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "problem_type": "single_label_classification",
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.22.1",
#   "vocab_size": 30522
# }
# Downloading:   0%|          | 0.00/268M [00:00<?, ?B/s]
# loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--gokuls--distilbert-base-Massive-intent/snapshots/1282c5096ee4deac235f13f2a1f4a5571f70852c/pytorch_model.bin
# All model checkpoint weights were used when initializing DistilBertForSequenceClassification.
#
# All the weights of DistilBertForSequenceClassification were initialized from the model checkpoint at gokuls/distilbert-base-Massive-intent.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use DistilBertForSequenceClassification for predictions without further training.
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--google--bert_uncased_L-2_H-128_A-2/snapshots/1ae49ff827beda5996998802695c4cac8e9932c6/config.json
# Model config BertConfig {
#   "_name_or_path": "google/bert_uncased_L-2_H-128_A-2",
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 128,
#   "id2label": {
#     "0": "datetime_query",
#     "1": "iot_hue_lightchange",
#     "10": "qa_currency",
#     "11": "transport_traffic",
#     "12": "general_quirky",
#     "13": "weather_query",
#     "14": "audio_volume_up",
#     "15": "email_addcontact",
#     "16": "takeaway_order",
#     "17": "email_querycontact",
#     "18": "iot_hue_lightup",
#     "19": "recommendation_locations",
#     "2": "transport_ticket",
#     "20": "play_audiobook",
#     "21": "lists_createoradd",
#     "22": "news_query",
#     "23": "alarm_query",
#     "24": "iot_wemo_on",
#     "25": "general_joke",
#     "26": "qa_definition",
#     "27": "social_query",
#     "28": "music_settings",
#     "29": "audio_volume_other",
#     "3": "takeaway_query",
#     "30": "calendar_remove",
#     "31": "iot_hue_lightdim",
#     "32": "calendar_query",
#     "33": "email_sendemail",
#     "34": "iot_cleaning",
#     "35": "audio_volume_down",
#     "36": "play_radio",
#     "37": "cooking_query",
#     "38": "datetime_convert",
#     "39": "qa_maths",
#     "4": "qa_stock",
#     "40": "iot_hue_lightoff",
#     "41": "iot_hue_lighton",
#     "42": "transport_query",
#     "43": "music_likeness",
#     "44": "email_query",
#     "45": "play_music",
#     "46": "audio_volume_mute",
#     "47": "social_post",
#     "48": "alarm_set",
#     "49": "qa_factoid",
#     "5": "general_greet",
#     "50": "calendar_set",
#     "51": "play_game",
#     "52": "alarm_remove",
#     "53": "lists_remove",
#     "54": "transport_taxi",
#     "55": "recommendation_movies",
#     "56": "iot_coffee",
#     "57": "music_query",
#     "58": "play_podcasts",
#     "59": "lists_query",
#     "6": "recommendation_events",
#     "7": "music_dislikeness",
#     "8": "iot_wemo_off",
#     "9": "cooking_recipe"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 512,
#   "label2id": {
#     "alarm_query": "23",
#     "alarm_remove": "52",
#     "alarm_set": "48",
#     "audio_volume_down": "35",
#     "audio_volume_mute": "46",
#     "audio_volume_other": "29",
#     "audio_volume_up": "14",
#     "calendar_query": "32",
#     "calendar_remove": "30",
#     "calendar_set": "50",
#     "cooking_query": "37",
#     "cooking_recipe": "9",
#     "datetime_convert": "38",
#     "datetime_query": "0",
#     "email_addcontact": "15",
#     "email_query": "44",
#     "email_querycontact": "17",
#     "email_sendemail": "33",
#     "general_greet": "5",
#     "general_joke": "25",
#     "general_quirky": "12",
#     "iot_cleaning": "34",
#     "iot_coffee": "56",
#     "iot_hue_lightchange": "1",
#     "iot_hue_lightdim": "31",
#     "iot_hue_lightoff": "40",
#     "iot_hue_lighton": "41",
#     "iot_hue_lightup": "18",
#     "iot_wemo_off": "8",
#     "iot_wemo_on": "24",
#     "lists_createoradd": "21",
#     "lists_query": "59",
#     "lists_remove": "53",
#     "music_dislikeness": "7",
#     "music_likeness": "43",
#     "music_query": "57",
#     "music_settings": "28",
#     "news_query": "22",
#     "play_audiobook": "20",
#     "play_game": "51",
#     "play_music": "45",
#     "play_podcasts": "58",
#     "play_radio": "36",
#     "qa_currency": "10",
#     "qa_definition": "26",
#     "qa_factoid": "49",
#     "qa_maths": "39",
#     "qa_stock": "4",
#     "recommendation_events": "6",
#     "recommendation_locations": "19",
#     "recommendation_movies": "55",
#     "social_post": "47",
#     "social_query": "27",
#     "takeaway_order": "16",
#     "takeaway_query": "3",
#     "transport_query": "42",
#     "transport_taxi": "54",
#     "transport_ticket": "2",
#     "transport_traffic": "11",
#     "weather_query": "13"
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 2,
#   "num_hidden_layers": 2,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.22.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--google--bert_uncased_L-2_H-128_A-2/snapshots/1ae49ff827beda5996998802695c4cac8e9932c6/pytorch_model.bin
# Some weights of the model checkpoint at google/bert_uncased_L-2_H-128_A-2 were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at google/bert_uncased_L-2_H-128_A-2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
## Evaluation metric ##

def compute_metrics(eval_preds):
    metric_acc = evaluate.load("accuracy")
    #metric_f1 = evaluate.load("f1")
    logits, labels = eval_preds
    predictions = np.argmax(logits, axis=-1)
    #return {'accuracy' : metric_acc.compute(predictions=predictions, references=labels), 'f1' : metric_f1.compute(predictions=predictions, references=labels, average= 'micro')}
    return metric_acc.compute(predictions=predictions, references=labels)

# %%
## Trainer ##

trainer = DistillationTrainer(
    student_model,
    training_args,
    teacher_model=teacher_model,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
    callbacks = [EarlyStoppingCallback(early_stopping_patience = 3)],
)
# Out:
# Cloning https://huggingface.co/gokuls/bert-tiny-Massive-intent-KD-distilBERT into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/gokuls/bert-tiny-Massive-intent-KD-distilBERT into local empty directory.
# Using cuda_amp half precision backend

# %%
## Training ##

trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 11514
#   Num Epochs = 50
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 36000
# You're using a DistilBertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='24480' max='36000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [24480/36000 20:13 < 09:31, 20.17 it/s, Epoch 34/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>10.979500</td>
#       <td>9.323637</td>
#       <td>0.291687</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>9.423900</td>
#       <td>7.979200</td>
#       <td>0.409247</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>8.263200</td>
#       <td>6.982390</td>
#       <td>0.481062</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>7.342500</td>
#       <td>6.154485</td>
#       <td>0.551402</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>6.560000</td>
#       <td>5.482856</td>
#       <td>0.606001</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>5.903200</td>
#       <td>4.899405</td>
#       <td>0.646335</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>5.307800</td>
#       <td>4.412856</td>
#       <td>0.691097</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>4.819000</td>
#       <td>4.015185</td>
#       <td>0.707329</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>4.386600</td>
#       <td>3.673428</td>
#       <td>0.732415</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>3.995400</td>
#       <td>3.372925</td>
#       <td>0.751599</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>3.676400</td>
#       <td>3.125117</td>
#       <td>0.759961</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>3.371200</td>
#       <td>2.907676</td>
#       <td>0.775209</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>3.103700</td>
#       <td>2.736118</td>
#       <td>0.778652</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>2.861700</td>
#       <td>2.579139</td>
#       <td>0.786030</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2.666700</td>
#       <td>2.438306</td>
#       <td>0.794393</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>2.476000</td>
#       <td>2.330055</td>
#       <td>0.794393</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>2.320300</td>
#       <td>2.209889</td>
#       <td>0.805214</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>2.169800</td>
#       <td>2.135094</td>
#       <td>0.810133</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>2.056300</td>
#       <td>2.055373</td>
#       <td>0.811117</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.929400</td>
#       <td>2.009995</td>
#       <td>0.818987</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.830400</td>
#       <td>1.956639</td>
#       <td>0.820954</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.731500</td>
#       <td>1.907577</td>
#       <td>0.822430</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.658700</td>
#       <td>1.851090</td>
#       <td>0.828333</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.587600</td>
#       <td>1.823007</td>
#       <td>0.829808</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.517300</td>
#       <td>1.800164</td>
#       <td>0.825873</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.467600</td>
#       <td>1.766740</td>
#       <td>0.827841</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.395600</td>
#       <td>1.751203</td>
#       <td>0.831284</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.343600</td>
#       <td>1.723251</td>
#       <td>0.829808</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.303100</td>
#       <td>1.680173</td>
#       <td>0.831776</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.258400</td>
#       <td>1.676830</td>
#       <td>0.832759</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.223300</td>
#       <td>1.661229</td>
#       <td>0.839646</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.188400</td>
#       <td>1.660757</td>
#       <td>0.835219</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.137400</td>
#       <td>1.619485</td>
#       <td>0.838662</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.129900</td>
#       <td>1.596916</td>
#       <td>0.837678</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-720
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-720/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-720/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-720/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-720/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-1440
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-1440/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-1440/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-1440/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-1440/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-2160
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-2160/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-2160/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-2160/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-2160/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-720] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-2880
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-2880/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-2880/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-2880/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-2880/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-1440] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-3600
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-3600/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-3600/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-3600/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-3600/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-2160] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-4320
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-4320/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-4320/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-4320/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-4320/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-2880] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-5040
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-5040/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-5040/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-5040/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-5040/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-3600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-5760
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-5760/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-5760/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-5760/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-5760/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-4320] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-6480
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-6480/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-6480/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-6480/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-6480/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-5040] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-7200
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-7200/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-7200/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-7200/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-7200/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-5760] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-7920
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-7920/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-7920/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-7920/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-7920/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-6480] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-8640
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-8640/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-8640/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-8640/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-8640/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-7200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-9360
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-9360/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-9360/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-9360/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-9360/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-7920] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-10080
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-10080/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-10080/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-10080/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-10080/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-8640] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-10800
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-10800/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-10800/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-10800/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-10800/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-9360] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-11520
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-11520/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-11520/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-11520/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-11520/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-10080] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-12240
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-12240/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-12240/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-12240/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-12240/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-10800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-12960
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-12960/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-12960/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-12960/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-12960/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-11520] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-13680
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-13680/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-13680/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-13680/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-13680/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-12240] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-14400
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-14400/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-14400/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-14400/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-14400/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-12960] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-15120
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-15120/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-15120/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-15120/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-15120/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-13680] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-15840
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-15840/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-15840/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-15840/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-15840/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-14400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-16560
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-16560/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-16560/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-16560/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-16560/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-15120] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-17280
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-17280/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-17280/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-17280/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-17280/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-15840] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-18000
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-18000/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-18000/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-18000/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-18000/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-16560] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-18720
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-18720/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-18720/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-18720/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-18720/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-18000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-19440
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-19440/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-19440/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-19440/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-19440/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-17280] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-20160
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-20160/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-20160/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-20160/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-20160/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-18720] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-20880
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-20880/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-20880/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-20880/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-20880/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-19440] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-21600
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-21600/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-21600/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-21600/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-21600/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-20160] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-22320
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-22320/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-22320/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-22320/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-22320/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-20880] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-23040
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-23040/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-23040/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-23040/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-23040/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-21600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-23760
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-23760/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-23760/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-23760/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-23760/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-23040] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT/checkpoint-24480
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-24480/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-24480/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-24480/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/checkpoint-24480/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-distilBERT/checkpoint-23760] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from bert-tiny-Massive-intent-KD-distilBERT/checkpoint-22320 (score: 0.8396458435809149).
# TrainOutput(global_step=24480, training_loss=3.3348690207487617, metrics={'train_runtime': 1213.7559, 'train_samples_per_second': 474.313, 'train_steps_per_second': 29.66, 'total_flos': 17306045619840.0, 'train_loss': 3.3348690207487617, 'epoch': 34.0})

# %%
### BERT-tiny model's convergence of loss takes a very very long time ###

# %%
## After the training the Best model will be used. Now evaluating the best model ##

## Evaluate ##

trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
#     <div>
#
#       <progress value='128' max='128' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [128/128 00:02]
#     </div>
# {'eval_loss': 1.6612293720245361,
#  'eval_accuracy': 0.8396458435809149,
#  'eval_runtime': 3.9833,
#  'eval_samples_per_second': 510.383,
#  'eval_steps_per_second': 32.134,
#  'epoch': 34.0}

# %%
## Evaluating the model on Test set ##

print('\nTest results : \n\n', trainer.predict(tokenized_datasets["test"]).metrics)
# Out:
# ***** Running Prediction *****
#   Num examples = 2974
#   Batch size = 16
# Test results :
#
#  {'test_loss': 1.8105820417404175, 'test_accuracy': 0.820107599193006, 'test_runtime': 5.5254, 'test_samples_per_second': 538.241, 'test_steps_per_second': 33.663}

# %%
## Computing All the other performance evaluation metics (precision, recall and f1) on the test set ##

## Predicted values ##

test_result = trainer.predict(tokenized_datasets["test"])
predicted_values = np.argmax(test_result.predictions, axis=1)
print("Predicted values : ", predicted_values)

## Actual values ##

actual_values = test_result.label_ids
print('Actual values : ', actual_values)

## Getting label id and names ##

target_names = list(label2id.keys())
labels = list(map(int, list(id2label.keys()))) ## Converting list of strings to list of integers ##


## Getting the classification report using sklearn ##

from sklearn.metrics import classification_report, accuracy_score

print('Accuracy : ', accuracy_score(actual_values, predicted_values))
print(classification_report(actual_values, predicted_values, labels= labels, target_names= target_names))
# Out:
# ***** Running Prediction *****
#   Num examples = 2974
#   Batch size = 16
# Predicted values :  [48 46 45 ... 44 44 44]
# Actual values :  [48 46  1 ... 44 44 44]
# Accuracy :  0.820107599193006
#                           precision    recall  f1-score   support
#
#           datetime_query       0.88      0.91      0.89        88
#      iot_hue_lightchange       0.78      0.89      0.83        36
#         transport_ticket       1.00      0.89      0.94        35
#           takeaway_query       0.83      0.71      0.77        35
#                 qa_stock       0.83      0.92      0.87        26
#            general_greet       0.00      0.00      0.00         1
#    recommendation_events       0.69      0.63      0.66        43
#        music_dislikeness       0.00      0.00      0.00         4
#             iot_wemo_off       0.68      0.72      0.70        18
#           cooking_recipe       0.86      0.92      0.89        72
#              qa_currency       0.86      0.95      0.90        39
#        transport_traffic       0.79      1.00      0.88        15
#           general_quirky       0.55      0.55      0.55       169
#            weather_query       0.93      0.96      0.94       156
#          audio_volume_up       0.40      0.77      0.53        13
#         email_addcontact       0.86      0.50      0.63        12
#           takeaway_order       0.81      0.77      0.79        22
#       email_querycontact       0.66      0.73      0.69        26
#          iot_hue_lightup       0.96      0.85      0.90        27
# recommendation_locations       0.74      0.90      0.81        31
#           play_audiobook       0.77      0.73      0.75        41
#        lists_createoradd       0.80      0.85      0.83        39
#               news_query       0.81      0.81      0.81       124
#              alarm_query       0.86      0.94      0.90        34
#              iot_wemo_on       1.00      0.10      0.18        10
#             general_joke       0.94      0.89      0.92        19
#            qa_definition       0.84      0.81      0.82        57
#             social_query       0.80      0.80      0.80        25
#           music_settings       0.67      0.33      0.44         6
#       audio_volume_other       0.00      0.00      0.00         6
#          calendar_remove       0.89      0.99      0.94        67
#         iot_hue_lightdim       0.83      0.95      0.89        21
#           calendar_query       0.69      0.83      0.75       126
#          email_sendemail       0.92      0.90      0.91       114
#             iot_cleaning       0.96      0.88      0.92        26
#        audio_volume_down       0.80      0.36      0.50        11
#               play_radio       0.88      0.88      0.88        72
#            cooking_query       0.00      0.00      0.00         0
#         datetime_convert       0.86      0.40      0.55        15
#                 qa_maths       0.73      0.76      0.75        25
#         iot_hue_lightoff       0.84      0.86      0.85        43
#          iot_hue_lighton       0.00      0.00      0.00         3
#          transport_query       0.78      0.75      0.76        51
#           music_likeness       0.82      0.64      0.72        36
#              email_query       0.87      0.92      0.89       119
#               play_music       0.78      0.88      0.83       176
#        audio_volume_mute       0.85      0.72      0.78        32
#              social_post       0.95      0.85      0.90        81
#                alarm_set       0.84      0.88      0.86        41
#               qa_factoid       0.70      0.67      0.68       141
#             calendar_set       0.92      0.88      0.90       209
#                play_game       0.81      0.83      0.82        35
#             alarm_remove       1.00      0.76      0.86        21
#             lists_remove       0.91      0.83      0.87        52
#           transport_taxi       0.96      1.00      0.98        23
#    recommendation_movies       0.72      0.65      0.68        20
#               iot_coffee       0.90      0.97      0.93        36
#              music_query       0.75      0.86      0.80        35
#            play_podcasts       0.98      0.87      0.92        63
#              lists_query       0.91      0.84      0.88        51
#
#                micro avg       0.82      0.82      0.82      2974
#                macro avg       0.76      0.72      0.73      2974
#             weighted avg       0.82      0.82      0.82      2974
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
## Saving the model on the hugging face hub ##

# save best model, metrics and create model card #

trainer.create_model_card(model_name=training_args.hub_model_id)
trainer.push_to_hub()


## Link for the model webpage ##

whoami = HfApi().whoami()
username = whoami['name']

print(f"Model webpage link: https://huggingface.co/{username}/{repo_name}")
# Out:
# Saving model checkpoint to bert-tiny-Massive-intent-KD-distilBERT
# Configuration saved in bert-tiny-Massive-intent-KD-distilBERT/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-distilBERT/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-distilBERT/special_tokens_map.json
# Upload file logs/events.out.tfevents.1663961788.bf5406322ee0.68.2:  14%|#4        | 3.34k/23.3k [00:00<?, ?B/s…
# Upload file logs/events.out.tfevents.1663963138.bf5406322ee0.68.4: 100%|##########| 369/369 [00:00<?, ?B/s]
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/gokuls/bert-tiny-Massive-intent-KD-distilBERT
#    f880de8..c9b60a1  main -> main
#
# WARNING:huggingface_hub.repository:remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/gokuls/bert-tiny-Massive-intent-KD-distilBERT
#    f880de8..c9b60a1  main -> main
# Model webpage link: https://huggingface.co/gokuls/bert-tiny-Massive-intent-KD-distilBERT

# %% [markdown]
# # Using BERT-base model and distilBERT model (multiple teacher model) for Knowledge Distillation

# %%
# Name for the repository on the huggingface hub #

repo_name = "bert-tiny-Massive-intent-KD-BERT_and_distilBERT"

# %%
## Teacher model : https://huggingface.co/gokuls/bert-base-Massive-intent ##
## Teacher model 2: https://huggingface.co/gokuls/distilbert-base-Massive-intent ##

# %%
student_id = "google/bert_uncased_L-2_H-128_A-2" ## using bert-tiny model
teacher_id_1 = "gokuls/bert-base-Massive-intent" ## Our pre-trained BERT model is used as teacher
teacher_id_2 = "gokuls/distilbert-base-Massive-intent" ## Our pre-trained distilBERT model is used as teacher

# %%
## Checking if the tokenizers of teacher and student model produces the same output ##

# tokenizer initialization #
teacher_tokenizer1 = AutoTokenizer.from_pretrained(teacher_id_1)
teacher_tokenizer2 = AutoTokenizer.from_pretrained(teacher_id_2)
student_tokenizer = AutoTokenizer.from_pretrained(student_id)

# sample input #
sample = "Testing tokenizers."

# Sanity check #
print('Teacher tokenizer 1: ', teacher_tokenizer1(sample))
print('Teacher tokenizer 2: ', teacher_tokenizer2(sample))
print('Student tokenizer: ', student_tokenizer(sample))

## Tokenization outputs are similar ##
# Out:
# Downloading:   0%|          | 0.00/360 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/711k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Teacher tokenizer 1:  {'input_ids': [101, 5604, 19204, 17629, 2015, 1012, 102], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1]}
# Teacher tokenizer 2:  {'input_ids': [101, 5604, 19204, 17629, 2015, 1012, 102], 'attention_mask': [1, 1, 1, 1, 1, 1, 1]}
# Student tokenizer:  {'input_ids': [101, 5604, 19204, 17629, 2015, 1012, 102], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1]}

# %%
tokenizer = AutoTokenizer.from_pretrained(teacher_id_2) ## Don't use the tokenizer from teacher_id_1 (BERT), since it produces token_type_id which is not needed by distilBERT ##
# Out:
# loading file vocab.txt from cache at /root/.cache/huggingface/hub/models--gokuls--distilbert-base-Massive-intent/snapshots/1282c5096ee4deac235f13f2a1f4a5571f70852c/vocab.txt
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--gokuls--distilbert-base-Massive-intent/snapshots/1282c5096ee4deac235f13f2a1f4a5571f70852c/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--gokuls--distilbert-base-Massive-intent/snapshots/1282c5096ee4deac235f13f2a1f4a5571f70852c/special_tokens_map.json
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--gokuls--distilbert-base-Massive-intent/snapshots/1282c5096ee4deac235f13f2a1f4a5571f70852c/tokenizer_config.json

# %%
## Tokenization ##

def tokenize_function(example):
    return tokenizer(example["utt"], truncation=True)

tokenized_datasets = raw_datasets.map(tokenize_function, batched=True)
# Out:
#   0%|          | 0/12 [00:00<?, ?ba/s]
#   0%|          | 0/3 [00:00<?, ?ba/s]
#   0%|          | 0/3 [00:00<?, ?ba/s]

# %%
## Data Pre-processing ##

tokenized_datasets = tokenized_datasets.remove_columns(['id', 'locale', 'partition','scenario','annot_utt', 'utt', 'worker_id', 'slot_method', 'judgments']) ## removing unwanted columns ##
tokenized_datasets = tokenized_datasets.rename_column("intent", "labels")
tokenized_datasets.set_format("torch")
tokenized_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['labels', 'input_ids', 'attention_mask'],
#         num_rows: 11514
#     })
#     validation: Dataset({
#         features: ['labels', 'input_ids', 'attention_mask'],
#         num_rows: 2033
#     })
#     test: Dataset({
#         features: ['labels', 'input_ids', 'attention_mask'],
#         num_rows: 2974
#     })
# })

# %%
class DistillationTrainingArguments(TrainingArguments):
    def __init__(self, *args, alpha=0.5, temperature=2.0, **kwargs):
        super().__init__(*args, **kwargs)
        
        self.alpha = alpha
        self.temperature = temperature
        
class DistillationTrainer(Trainer):
    def __init__(self, *args, teacher_model_1=None, teacher_model_2=None, **kwargs):
        super().__init__(*args, **kwargs)
        self.teacher1 = teacher_model_1
        self.teacher2 = teacher_model_2
        # student and teacher on same device #
        self._move_model_to_device(self.teacher1,self.model.device)
        self._move_model_to_device(self.teacher2,self.model.device)
        self.teacher1.eval()
        self.teacher2.eval()

    def compute_loss(self, model, inputs, return_outputs=False):

        # compute student output #
        outputs_student = model(**inputs)
        student_loss=outputs_student.loss # output from gold labels
        # compute teacher output #
        with torch.no_grad():
            outputs_teacher1 = self.teacher1(**inputs)
            outputs_teacher2 = self.teacher2(**inputs)
        
        # assert size #
        assert outputs_student.logits.size() == outputs_teacher1.logits.size()
        assert outputs_student.logits.size() == outputs_teacher2.logits.size()
        
        # Soften probabilities and compute distillation loss #
        loss_function = nn.KLDivLoss(reduction="batchmean")
        loss_logits = (loss_function(
            F.log_softmax(outputs_student.logits / self.args.temperature, dim=-1),
            F.softmax(outputs_teacher1.logits / self.args.temperature, dim=-1)) * (self.args.temperature ** 2)) + (loss_function(
            F.log_softmax(outputs_student.logits / self.args.temperature, dim=-1),
            F.softmax(outputs_teacher2.logits / self.args.temperature, dim=-1)) * (self.args.temperature ** 2))
        # Return weighted student loss #
        loss = self.args.alpha * student_loss + (1. - self.args.alpha) * loss_logits
        return (loss, outputs_student) if return_outputs else loss

# %%
# create label2id, id2label dicts #
labels = tokenized_datasets["train"].features["labels"].names
num_labels = len(labels)
label2id, id2label = dict(), dict()
for i, label in enumerate(labels):
    label2id[label] = str(i)
    id2label[str(i)] = label

# training args #
training_args = DistillationTrainingArguments(
    output_dir=repo_name,
    num_train_epochs=50,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    fp16=True,
    learning_rate=5e-5,
    seed=33,
    # logging & evaluation strategies #
    logging_dir=f"{repo_name}/logs",
    logging_strategy="epoch",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    save_total_limit=2,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    report_to="tensorboard",
    # push to hub parameters #
    push_to_hub=True,
    hub_strategy="every_save",
    hub_model_id=repo_name,
    hub_token=HfFolder.get_token(),
    # distilation parameters #
    alpha=0.5,
    temperature=3.0
    )

# data_collator #
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# Teacher models #
teacher_model1 = AutoModelForSequenceClassification.from_pretrained(
    teacher_id_1,
    num_labels=num_labels, 
    id2label=id2label,
    label2id=label2id,
)

teacher_model2 = AutoModelForSequenceClassification.from_pretrained(
    teacher_id_2,
    num_labels=num_labels, 
    id2label=id2label,
    label2id=label2id,
)

# Student model #
student_model = AutoModelForSequenceClassification.from_pretrained(
    student_id,
    num_labels=num_labels, 
    id2label=id2label,
    label2id=label2id,
)
# Out:
# PyTorch: setting up devices
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--gokuls--bert-base-Massive-intent/snapshots/d53c46768bfbaae4c67389c3aac3e1856d6ad9e5/config.json
# Model config BertConfig {
#   "_name_or_path": "gokuls/bert-base-Massive-intent",
#   "architectures": [
#     "BertForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "datetime_query",
#     "1": "iot_hue_lightchange",
#     "10": "qa_currency",
#     "11": "transport_traffic",
#     "12": "general_quirky",
#     "13": "weather_query",
#     "14": "audio_volume_up",
#     "15": "email_addcontact",
#     "16": "takeaway_order",
#     "17": "email_querycontact",
#     "18": "iot_hue_lightup",
#     "19": "recommendation_locations",
#     "2": "transport_ticket",
#     "20": "play_audiobook",
#     "21": "lists_createoradd",
#     "22": "news_query",
#     "23": "alarm_query",
#     "24": "iot_wemo_on",
#     "25": "general_joke",
#     "26": "qa_definition",
#     "27": "social_query",
#     "28": "music_settings",
#     "29": "audio_volume_other",
#     "3": "takeaway_query",
#     "30": "calendar_remove",
#     "31": "iot_hue_lightdim",
#     "32": "calendar_query",
#     "33": "email_sendemail",
#     "34": "iot_cleaning",
#     "35": "audio_volume_down",
#     "36": "play_radio",
#     "37": "cooking_query",
#     "38": "datetime_convert",
#     "39": "qa_maths",
#     "4": "qa_stock",
#     "40": "iot_hue_lightoff",
#     "41": "iot_hue_lighton",
#     "42": "transport_query",
#     "43": "music_likeness",
#     "44": "email_query",
#     "45": "play_music",
#     "46": "audio_volume_mute",
#     "47": "social_post",
#     "48": "alarm_set",
#     "49": "qa_factoid",
#     "5": "general_greet",
#     "50": "calendar_set",
#     "51": "play_game",
#     "52": "alarm_remove",
#     "53": "lists_remove",
#     "54": "transport_taxi",
#     "55": "recommendation_movies",
#     "56": "iot_coffee",
#     "57": "music_query",
#     "58": "play_podcasts",
#     "59": "lists_query",
#     "6": "recommendation_events",
#     "7": "music_dislikeness",
#     "8": "iot_wemo_off",
#     "9": "cooking_recipe"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "alarm_query": "23",
#     "alarm_remove": "52",
#     "alarm_set": "48",
#     "audio_volume_down": "35",
#     "audio_volume_mute": "46",
#     "audio_volume_other": "29",
#     "audio_volume_up": "14",
#     "calendar_query": "32",
#     "calendar_remove": "30",
#     "calendar_set": "50",
#     "cooking_query": "37",
#     "cooking_recipe": "9",
#     "datetime_convert": "38",
#     "datetime_query": "0",
#     "email_addcontact": "15",
#     "email_query": "44",
#     "email_querycontact": "17",
#     "email_sendemail": "33",
#     "general_greet": "5",
#     "general_joke": "25",
#     "general_quirky": "12",
#     "iot_cleaning": "34",
#     "iot_coffee": "56",
#     "iot_hue_lightchange": "1",
#     "iot_hue_lightdim": "31",
#     "iot_hue_lightoff": "40",
#     "iot_hue_lighton": "41",
#     "iot_hue_lightup": "18",
#     "iot_wemo_off": "8",
#     "iot_wemo_on": "24",
#     "lists_createoradd": "21",
#     "lists_query": "59",
#     "lists_remove": "53",
#     "music_dislikeness": "7",
#     "music_likeness": "43",
#     "music_query": "57",
#     "music_settings": "28",
#     "news_query": "22",
#     "play_audiobook": "20",
#     "play_game": "51",
#     "play_music": "45",
#     "play_podcasts": "58",
#     "play_radio": "36",
#     "qa_currency": "10",
#     "qa_definition": "26",
#     "qa_factoid": "49",
#     "qa_maths": "39",
#     "qa_stock": "4",
#     "recommendation_events": "6",
#     "recommendation_locations": "19",
#     "recommendation_movies": "55",
#     "social_post": "47",
#     "social_query": "27",
#     "takeaway_order": "16",
#     "takeaway_query": "3",
#     "transport_query": "42",
#     "transport_taxi": "54",
#     "transport_ticket": "2",
#     "transport_traffic": "11",
#     "weather_query": "13"
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "torch_dtype": "float32",
#   "transformers_version": "4.22.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--gokuls--bert-base-Massive-intent/snapshots/d53c46768bfbaae4c67389c3aac3e1856d6ad9e5/pytorch_model.bin
# All model checkpoint weights were used when initializing BertForSequenceClassification.
#
# All the weights of BertForSequenceClassification were initialized from the model checkpoint at gokuls/bert-base-Massive-intent.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForSequenceClassification for predictions without further training.
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--gokuls--distilbert-base-Massive-intent/snapshots/1282c5096ee4deac235f13f2a1f4a5571f70852c/config.json
# Model config DistilBertConfig {
#   "_name_or_path": "gokuls/distilbert-base-Massive-intent",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForSequenceClassification"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "id2label": {
#     "0": "datetime_query",
#     "1": "iot_hue_lightchange",
#     "10": "qa_currency",
#     "11": "transport_traffic",
#     "12": "general_quirky",
#     "13": "weather_query",
#     "14": "audio_volume_up",
#     "15": "email_addcontact",
#     "16": "takeaway_order",
#     "17": "email_querycontact",
#     "18": "iot_hue_lightup",
#     "19": "recommendation_locations",
#     "2": "transport_ticket",
#     "20": "play_audiobook",
#     "21": "lists_createoradd",
#     "22": "news_query",
#     "23": "alarm_query",
#     "24": "iot_wemo_on",
#     "25": "general_joke",
#     "26": "qa_definition",
#     "27": "social_query",
#     "28": "music_settings",
#     "29": "audio_volume_other",
#     "3": "takeaway_query",
#     "30": "calendar_remove",
#     "31": "iot_hue_lightdim",
#     "32": "calendar_query",
#     "33": "email_sendemail",
#     "34": "iot_cleaning",
#     "35": "audio_volume_down",
#     "36": "play_radio",
#     "37": "cooking_query",
#     "38": "datetime_convert",
#     "39": "qa_maths",
#     "4": "qa_stock",
#     "40": "iot_hue_lightoff",
#     "41": "iot_hue_lighton",
#     "42": "transport_query",
#     "43": "music_likeness",
#     "44": "email_query",
#     "45": "play_music",
#     "46": "audio_volume_mute",
#     "47": "social_post",
#     "48": "alarm_set",
#     "49": "qa_factoid",
#     "5": "general_greet",
#     "50": "calendar_set",
#     "51": "play_game",
#     "52": "alarm_remove",
#     "53": "lists_remove",
#     "54": "transport_taxi",
#     "55": "recommendation_movies",
#     "56": "iot_coffee",
#     "57": "music_query",
#     "58": "play_podcasts",
#     "59": "lists_query",
#     "6": "recommendation_events",
#     "7": "music_dislikeness",
#     "8": "iot_wemo_off",
#     "9": "cooking_recipe"
#   },
#   "initializer_range": 0.02,
#   "label2id": {
#     "alarm_query": "23",
#     "alarm_remove": "52",
#     "alarm_set": "48",
#     "audio_volume_down": "35",
#     "audio_volume_mute": "46",
#     "audio_volume_other": "29",
#     "audio_volume_up": "14",
#     "calendar_query": "32",
#     "calendar_remove": "30",
#     "calendar_set": "50",
#     "cooking_query": "37",
#     "cooking_recipe": "9",
#     "datetime_convert": "38",
#     "datetime_query": "0",
#     "email_addcontact": "15",
#     "email_query": "44",
#     "email_querycontact": "17",
#     "email_sendemail": "33",
#     "general_greet": "5",
#     "general_joke": "25",
#     "general_quirky": "12",
#     "iot_cleaning": "34",
#     "iot_coffee": "56",
#     "iot_hue_lightchange": "1",
#     "iot_hue_lightdim": "31",
#     "iot_hue_lightoff": "40",
#     "iot_hue_lighton": "41",
#     "iot_hue_lightup": "18",
#     "iot_wemo_off": "8",
#     "iot_wemo_on": "24",
#     "lists_createoradd": "21",
#     "lists_query": "59",
#     "lists_remove": "53",
#     "music_dislikeness": "7",
#     "music_likeness": "43",
#     "music_query": "57",
#     "music_settings": "28",
#     "news_query": "22",
#     "play_audiobook": "20",
#     "play_game": "51",
#     "play_music": "45",
#     "play_podcasts": "58",
#     "play_radio": "36",
#     "qa_currency": "10",
#     "qa_definition": "26",
#     "qa_factoid": "49",
#     "qa_maths": "39",
#     "qa_stock": "4",
#     "recommendation_events": "6",
#     "recommendation_locations": "19",
#     "recommendation_movies": "55",
#     "social_post": "47",
#     "social_query": "27",
#     "takeaway_order": "16",
#     "takeaway_query": "3",
#     "transport_query": "42",
#     "transport_taxi": "54",
#     "transport_ticket": "2",
#     "transport_traffic": "11",
#     "weather_query": "13"
#   },
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "problem_type": "single_label_classification",
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.22.1",
#   "vocab_size": 30522
# }
#
# loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--gokuls--distilbert-base-Massive-intent/snapshots/1282c5096ee4deac235f13f2a1f4a5571f70852c/pytorch_model.bin
# All model checkpoint weights were used when initializing DistilBertForSequenceClassification.
#
# All the weights of DistilBertForSequenceClassification were initialized from the model checkpoint at gokuls/distilbert-base-Massive-intent.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use DistilBertForSequenceClassification for predictions without further training.
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--google--bert_uncased_L-2_H-128_A-2/snapshots/1ae49ff827beda5996998802695c4cac8e9932c6/config.json
# Model config BertConfig {
#   "_name_or_path": "google/bert_uncased_L-2_H-128_A-2",
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 128,
#   "id2label": {
#     "0": "datetime_query",
#     "1": "iot_hue_lightchange",
#     "10": "qa_currency",
#     "11": "transport_traffic",
#     "12": "general_quirky",
#     "13": "weather_query",
#     "14": "audio_volume_up",
#     "15": "email_addcontact",
#     "16": "takeaway_order",
#     "17": "email_querycontact",
#     "18": "iot_hue_lightup",
#     "19": "recommendation_locations",
#     "2": "transport_ticket",
#     "20": "play_audiobook",
#     "21": "lists_createoradd",
#     "22": "news_query",
#     "23": "alarm_query",
#     "24": "iot_wemo_on",
#     "25": "general_joke",
#     "26": "qa_definition",
#     "27": "social_query",
#     "28": "music_settings",
#     "29": "audio_volume_other",
#     "3": "takeaway_query",
#     "30": "calendar_remove",
#     "31": "iot_hue_lightdim",
#     "32": "calendar_query",
#     "33": "email_sendemail",
#     "34": "iot_cleaning",
#     "35": "audio_volume_down",
#     "36": "play_radio",
#     "37": "cooking_query",
#     "38": "datetime_convert",
#     "39": "qa_maths",
#     "4": "qa_stock",
#     "40": "iot_hue_lightoff",
#     "41": "iot_hue_lighton",
#     "42": "transport_query",
#     "43": "music_likeness",
#     "44": "email_query",
#     "45": "play_music",
#     "46": "audio_volume_mute",
#     "47": "social_post",
#     "48": "alarm_set",
#     "49": "qa_factoid",
#     "5": "general_greet",
#     "50": "calendar_set",
#     "51": "play_game",
#     "52": "alarm_remove",
#     "53": "lists_remove",
#     "54": "transport_taxi",
#     "55": "recommendation_movies",
#     "56": "iot_coffee",
#     "57": "music_query",
#     "58": "play_podcasts",
#     "59": "lists_query",
#     "6": "recommendation_events",
#     "7": "music_dislikeness",
#     "8": "iot_wemo_off",
#     "9": "cooking_recipe"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 512,
#   "label2id": {
#     "alarm_query": "23",
#     "alarm_remove": "52",
#     "alarm_set": "48",
#     "audio_volume_down": "35",
#     "audio_volume_mute": "46",
#     "audio_volume_other": "29",
#     "audio_volume_up": "14",
#     "calendar_query": "32",
#     "calendar_remove": "30",
#     "calendar_set": "50",
#     "cooking_query": "37",
#     "cooking_recipe": "9",
#     "datetime_convert": "38",
#     "datetime_query": "0",
#     "email_addcontact": "15",
#     "email_query": "44",
#     "email_querycontact": "17",
#     "email_sendemail": "33",
#     "general_greet": "5",
#     "general_joke": "25",
#     "general_quirky": "12",
#     "iot_cleaning": "34",
#     "iot_coffee": "56",
#     "iot_hue_lightchange": "1",
#     "iot_hue_lightdim": "31",
#     "iot_hue_lightoff": "40",
#     "iot_hue_lighton": "41",
#     "iot_hue_lightup": "18",
#     "iot_wemo_off": "8",
#     "iot_wemo_on": "24",
#     "lists_createoradd": "21",
#     "lists_query": "59",
#     "lists_remove": "53",
#     "music_dislikeness": "7",
#     "music_likeness": "43",
#     "music_query": "57",
#     "music_settings": "28",
#     "news_query": "22",
#     "play_audiobook": "20",
#     "play_game": "51",
#     "play_music": "45",
#     "play_podcasts": "58",
#     "play_radio": "36",
#     "qa_currency": "10",
#     "qa_definition": "26",
#     "qa_factoid": "49",
#     "qa_maths": "39",
#     "qa_stock": "4",
#     "recommendation_events": "6",
#     "recommendation_locations": "19",
#     "recommendation_movies": "55",
#     "social_post": "47",
#     "social_query": "27",
#     "takeaway_order": "16",
#     "takeaway_query": "3",
#     "transport_query": "42",
#     "transport_taxi": "54",
#     "transport_ticket": "2",
#     "transport_traffic": "11",
#     "weather_query": "13"
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 2,
#   "num_hidden_layers": 2,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.22.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--google--bert_uncased_L-2_H-128_A-2/snapshots/1ae49ff827beda5996998802695c4cac8e9932c6/pytorch_model.bin
# Some weights of the model checkpoint at google/bert_uncased_L-2_H-128_A-2 were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at google/bert_uncased_L-2_H-128_A-2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
## Evaluation metric ##

def compute_metrics(eval_preds):
    metric_acc = evaluate.load("accuracy")
    logits, labels = eval_preds
    predictions = np.argmax(logits, axis=-1)
    return metric_acc.compute(predictions=predictions, references=labels)

# %%
trainer = DistillationTrainer(
    student_model,
    training_args,
    teacher_model_1=teacher_model1,
    teacher_model_2=teacher_model2,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
    callbacks = [EarlyStoppingCallback(early_stopping_patience = 3)],
)
# Out:
# /content/bert-tiny-Massive-intent-KD-BERT_and_distilBERT is already a clone of https://huggingface.co/gokuls/bert-tiny-Massive-intent-KD-BERT_and_distilBERT. Make sure you pull the latest changes with `repo.git_pull()`.
# WARNING:huggingface_hub.repository:/content/bert-tiny-Massive-intent-KD-BERT_and_distilBERT is already a clone of https://huggingface.co/gokuls/bert-tiny-Massive-intent-KD-BERT_and_distilBERT. Make sure you pull the latest changes with `repo.git_pull()`.
# Using cuda_amp half precision backend

# %%
## Training ##

trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 11514
#   Num Epochs = 50
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 36000
# You're using a DistilBertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='30960' max='36000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [30960/36000 34:59 < 05:41, 14.75 it/s, Epoch 43/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>15.115900</td>
#       <td>12.825702</td>
#       <td>0.225283</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>12.994900</td>
#       <td>10.989080</td>
#       <td>0.430398</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>11.386500</td>
#       <td>9.562173</td>
#       <td>0.503197</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>10.055300</td>
#       <td>8.369985</td>
#       <td>0.553861</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>8.943100</td>
#       <td>7.412732</td>
#       <td>0.610428</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>8.013500</td>
#       <td>6.618501</td>
#       <td>0.628628</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>7.198700</td>
#       <td>5.951724</td>
#       <td>0.681751</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>6.516800</td>
#       <td>5.387944</td>
#       <td>0.711756</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>5.935200</td>
#       <td>4.942646</td>
#       <td>0.727496</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>5.429900</td>
#       <td>4.563731</td>
#       <td>0.741269</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>5.001700</td>
#       <td>4.237939</td>
#       <td>0.758485</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>4.595100</td>
#       <td>3.969860</td>
#       <td>0.767831</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>4.284900</td>
#       <td>3.741615</td>
#       <td>0.773733</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>3.991000</td>
#       <td>3.550194</td>
#       <td>0.786522</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>3.745500</td>
#       <td>3.408985</td>
#       <td>0.789966</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>3.531500</td>
#       <td>3.305304</td>
#       <td>0.791441</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>3.345000</td>
#       <td>3.167028</td>
#       <td>0.800295</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>3.176700</td>
#       <td>3.073852</td>
#       <td>0.801279</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>3.032200</td>
#       <td>2.992733</td>
#       <td>0.804722</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.886400</td>
#       <td>2.936616</td>
#       <td>0.803738</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>2.772800</td>
#       <td>2.866592</td>
#       <td>0.809149</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>2.673200</td>
#       <td>2.814607</td>
#       <td>0.812592</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>2.572600</td>
#       <td>2.758773</td>
#       <td>0.819479</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>2.493000</td>
#       <td>2.731909</td>
#       <td>0.827349</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>2.418300</td>
#       <td>2.684716</td>
#       <td>0.824889</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>2.352600</td>
#       <td>2.631704</td>
#       <td>0.832268</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>2.270900</td>
#       <td>2.607144</td>
#       <td>0.828824</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>2.212500</td>
#       <td>2.598220</td>
#       <td>0.832268</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>2.155600</td>
#       <td>2.554587</td>
#       <td>0.833743</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>2.104200</td>
#       <td>2.527817</td>
#       <td>0.831776</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>2.054000</td>
#       <td>2.500525</td>
#       <td>0.841121</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>2.015400</td>
#       <td>2.489130</td>
#       <td>0.834727</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.978500</td>
#       <td>2.463339</td>
#       <td>0.836695</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.952100</td>
#       <td>2.445074</td>
#       <td>0.842105</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.924700</td>
#       <td>2.437045</td>
#       <td>0.841613</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.874100</td>
#       <td>2.419696</td>
#       <td>0.844565</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.865900</td>
#       <td>2.408127</td>
#       <td>0.840630</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.836700</td>
#       <td>2.397907</td>
#       <td>0.842597</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.815300</td>
#       <td>2.375814</td>
#       <td>0.845057</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.764100</td>
#       <td>2.372915</td>
#       <td>0.847024</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>1.760800</td>
#       <td>2.368322</td>
#       <td>0.846040</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1.764700</td>
#       <td>2.362826</td>
#       <td>0.844565</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1.765600</td>
#       <td>2.349179</td>
#       <td>0.847024</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-720
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-720/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-720/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-720/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-720/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-1440
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-1440/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-1440/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-1440/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-1440/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-2160
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-2160/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-2160/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-2160/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-2160/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-720] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-2880
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-2880/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-2880/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-2880/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-2880/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-1440] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-3600
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-3600/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-3600/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-3600/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-3600/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-2160] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-4320
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-4320/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-4320/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-4320/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-4320/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-2880] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-5040
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-5040/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-5040/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-5040/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-5040/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-3600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-5760
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-5760/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-5760/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-5760/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-5760/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-4320] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-6480
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-6480/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-6480/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-6480/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-6480/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-5040] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-7200
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-7200/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-7200/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-7200/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-7200/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-5760] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-7920
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-7920/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-7920/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-7920/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-7920/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-6480] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-8640
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-8640/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-8640/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-8640/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-8640/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-7200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-9360
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-9360/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-9360/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-9360/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-9360/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-7920] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-10080
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-10080/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-10080/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-10080/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-10080/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-8640] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-10800
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-10800/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-10800/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-10800/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-10800/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-9360] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-11520
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-11520/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-11520/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-11520/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-11520/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-10080] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-12240
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-12240/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-12240/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-12240/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-12240/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-10800] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-12960
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-12960/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-12960/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-12960/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-12960/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-11520] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-13680
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-13680/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-13680/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-13680/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-13680/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-12240] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-14400
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-14400/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-14400/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-14400/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-14400/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-12960] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-15120
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-15120/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-15120/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-15120/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-15120/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-13680] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-15840
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-15840/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-15840/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-15840/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-15840/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-14400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-16560
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-16560/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-16560/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-16560/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-16560/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-15120] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-17280
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-17280/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-17280/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-17280/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-17280/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-15840] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-18000
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-18000/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-18000/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-18000/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-18000/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-16560] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-18720
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-18720/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-18720/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-18720/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-18720/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-17280] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-19440
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-19440/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-19440/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-19440/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-19440/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-18000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-20160
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-20160/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-20160/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-20160/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-20160/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-19440] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-20880
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-20880/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-20880/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-20880/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-20880/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-18720] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-21600
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-21600/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-21600/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-21600/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-21600/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-20160] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-22320
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-22320/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-22320/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-22320/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-22320/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-20880] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-23040
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-23040/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-23040/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-23040/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-23040/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-21600] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-23760
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-23760/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-23760/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-23760/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-23760/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-23040] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-24480
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-24480/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-24480/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-24480/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-24480/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-22320] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-25200
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-25200/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-25200/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-25200/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-25200/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-23760] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-25920
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-25920/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-25920/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-25920/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-25920/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-24480] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-26640
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-26640/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-26640/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-26640/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-26640/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-25200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-27360
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-27360/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-27360/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-27360/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-27360/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-26640] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-28080
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-28080/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-28080/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-28080/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-28080/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-25920] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-28800
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-28800/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-28800/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-28800/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-28800/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-27360] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-29520
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-29520/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-29520/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-29520/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-29520/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-28080] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-30240
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-30240/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-30240/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-30240/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-30240/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-29520] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-30960
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-30960/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-30960/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-30960/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-30960/special_tokens_map.json
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Deleting older checkpoint [bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-30240] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from bert-tiny-Massive-intent-KD-BERT_and_distilBERT/checkpoint-28800 (score: 0.8470241023118544).
# TrainOutput(global_step=30960, training_loss=4.12970725756899, metrics={'train_runtime': 2099.2951, 'train_samples_per_second': 274.235, 'train_steps_per_second': 17.149, 'total_flos': 21871399613904.0, 'train_loss': 4.12970725756899, 'epoch': 43.0})

# %%
## After the training the Best model will be used. Now evaluating the best model ##

## Evaluate ##

trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 2033
#   Batch size = 16
#     <div>
#
#       <progress value='128' max='128' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [128/128 00:03]
#     </div>
# {'eval_loss': 2.372915267944336,
#  'eval_accuracy': 0.8470241023118544,
#  'eval_runtime': 5.8714,
#  'eval_samples_per_second': 346.255,
#  'eval_steps_per_second': 21.801,
#  'epoch': 43.0}

# %%
## Evaluating the model on Test set ##

print('\nTest results : \n\n', trainer.predict(tokenized_datasets["test"]).metrics)
# Out:
# ***** Running Prediction *****
#   Num examples = 2974
#   Batch size = 16
# Test results :
#
#  {'test_loss': 2.537945032119751, 'test_accuracy': 0.8275050437121722, 'test_runtime': 9.1439, 'test_samples_per_second': 325.242, 'test_steps_per_second': 20.341}

# %%
## Computing All the other performance evaluation metics (precision, recall and f1) on the test set ##

## Predicted values ##

test_result = trainer.predict(tokenized_datasets["test"])
predicted_values = np.argmax(test_result.predictions, axis=1)
print("Predicted values : ", predicted_values)

## Actual values ##

actual_values = test_result.label_ids
print('Actual values : ', actual_values)

## Getting label id and names ##

target_names = list(label2id.keys())
labels = list(map(int, list(id2label.keys()))) ## Converting list of strings to list of integers ##


## Getting the classification report using sklearn ##

from sklearn.metrics import classification_report, accuracy_score

print('Accuracy : ', accuracy_score(actual_values, predicted_values))
print(classification_report(actual_values, predicted_values, labels= labels, target_names= target_names))
# Out:
# ***** Running Prediction *****
#   Num examples = 2974
#   Batch size = 16
# Predicted values :  [48 46 49 ... 44 44 44]
# Actual values :  [48 46  1 ... 44 44 44]
# Accuracy :  0.8275050437121722
#                           precision    recall  f1-score   support
#
#           datetime_query       0.84      0.92      0.88        88
#      iot_hue_lightchange       0.72      0.86      0.78        36
#         transport_ticket       0.97      0.91      0.94        35
#           takeaway_query       0.90      0.74      0.81        35
#                 qa_stock       0.81      0.96      0.88        26
#            general_greet       0.00      0.00      0.00         1
#    recommendation_events       0.69      0.67      0.68        43
#        music_dislikeness       0.00      0.00      0.00         4
#             iot_wemo_off       1.00      0.83      0.91        18
#           cooking_recipe       0.88      0.92      0.90        72
#              qa_currency       0.93      0.95      0.94        39
#        transport_traffic       0.79      1.00      0.88        15
#           general_quirky       0.56      0.56      0.56       169
#            weather_query       0.92      0.92      0.92       156
#          audio_volume_up       0.56      0.77      0.65        13
#         email_addcontact       0.56      0.42      0.48        12
#           takeaway_order       0.72      0.82      0.77        22
#       email_querycontact       0.66      0.73      0.69        26
#          iot_hue_lightup       0.95      0.67      0.78        27
# recommendation_locations       0.90      0.84      0.87        31
#           play_audiobook       0.81      0.73      0.77        41
#        lists_createoradd       0.82      0.85      0.84        39
#               news_query       0.81      0.81      0.81       124
#              alarm_query       0.92      0.97      0.94        34
#              iot_wemo_on       1.00      0.80      0.89        10
#             general_joke       0.94      0.89      0.92        19
#            qa_definition       0.86      0.77      0.81        57
#             social_query       0.86      0.76      0.81        25
#           music_settings       0.67      0.33      0.44         6
#       audio_volume_other       0.00      0.00      0.00         6
#          calendar_remove       0.89      0.99      0.94        67
#         iot_hue_lightdim       0.88      1.00      0.93        21
#           calendar_query       0.69      0.78      0.73       126
#          email_sendemail       0.91      0.92      0.91       114
#             iot_cleaning       0.96      0.92      0.94        26
#        audio_volume_down       0.82      0.82      0.82        11
#               play_radio       0.89      0.89      0.89        72
#            cooking_query       0.00      0.00      0.00         0
#         datetime_convert       0.78      0.47      0.58        15
#                 qa_maths       0.77      0.80      0.78        25
#         iot_hue_lightoff       0.93      0.86      0.89        43
#          iot_hue_lighton       0.00      0.00      0.00         3
#          transport_query       0.78      0.76      0.77        51
#           music_likeness       0.76      0.61      0.68        36
#              email_query       0.92      0.93      0.93       119
#               play_music       0.80      0.89      0.84       176
#        audio_volume_mute       0.88      0.88      0.88        32
#              social_post       0.96      0.86      0.91        81
#                alarm_set       0.84      0.88      0.86        41
#               qa_factoid       0.66      0.72      0.69       141
#             calendar_set       0.91      0.89      0.90       209
#                play_game       0.80      0.80      0.80        35
#             alarm_remove       0.95      0.86      0.90        21
#             lists_remove       0.98      0.87      0.92        52
#           transport_taxi       0.96      1.00      0.98        23
#    recommendation_movies       0.76      0.65      0.70        20
#               iot_coffee       0.89      0.94      0.92        36
#              music_query       0.74      0.83      0.78        35
#            play_podcasts       0.96      0.87      0.92        63
#              lists_query       0.93      0.78      0.85        51
#
#                micro avg       0.83      0.83      0.83      2974
#                macro avg       0.77      0.75      0.75      2974
#             weighted avg       0.83      0.83      0.83      2974
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
## Saving the model on the hugging face hub ##

# save best model, metrics and create model card #

trainer.create_model_card(model_name=training_args.hub_model_id)
trainer.push_to_hub()


## Link for the model webpage ##

whoami = HfApi().whoami()
username = whoami['name']

print(f"Model webpage link: https://huggingface.co/{username}/{repo_name}")
# Out:
# Saving model checkpoint to bert-tiny-Massive-intent-KD-BERT_and_distilBERT
# Configuration saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/config.json
# Model weights saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/pytorch_model.bin
# tokenizer config file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/tokenizer_config.json
# Special tokens file saved in bert-tiny-Massive-intent-KD-BERT_and_distilBERT/special_tokens_map.json
# Upload file logs/events.out.tfevents.1664045154.ce181c7f3327.10095.2:  12%|#2        | 3.34k/27.6k [00:00<?, ?…
# Upload file logs/events.out.tfevents.1664047261.ce181c7f3327.10095.4: 100%|##########| 369/369 [00:00<?, ?B/s]
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/gokuls/bert-tiny-Massive-intent-KD-BERT_and_distilBERT
#    9db37d9..d2b426f  main -> main
#
# WARNING:huggingface_hub.repository:remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/gokuls/bert-tiny-Massive-intent-KD-BERT_and_distilBERT
#    9db37d9..d2b426f  main -> main
# Model webpage link: https://huggingface.co/gokuls/bert-tiny-Massive-intent-KD-BERT_and_distilBERT
